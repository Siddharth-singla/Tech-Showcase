# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('EDA_Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 524   1820000  3000         2          1        1         1          0
# 525   1767150  2400         3          1        1         0          0
# 526   1750000  3620         2          1        1         1          0
# 527   1750000  2910         3          1        1         0          0
# 528   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
df['bedrooms']
# Out:
# 0      4
# 1      4
# 2      3
# 3      4
# 4      4
#       ..
# 524    2
# 525    3
# 526    2
# 527    3
# 528    3
# Name: bedrooms, Length: 529, dtype: int64

# %%
sns.histplot(df['area'],color='g',bins=30,kde=True,)
plt.title('housing bar graph')
plt.yticks(np.arange(0,81, step=100))
plt.xticks(np.arange(0,5, step=1))
plt.grid()
plt.show()

# %%
df.corr()
# Out:
#                      price      area  bedrooms  bathrooms   stories  mainroad  \
# price             1.000000  0.559721  0.362441   0.522900  0.435335  0.294341
# area              0.559721  1.000000  0.160775   0.225602  0.138348  0.305975
# bedrooms          0.362441  0.160775  1.000000   0.359386  0.410999 -0.013951
# bathrooms         0.522900  0.225602  0.359386   1.000000  0.330982  0.042716
# stories           0.435335  0.138348  0.410999   0.330982  1.000000  0.126531
# mainroad          0.294341  0.305975 -0.013951   0.042716  0.126531  1.000000
# guestroom         0.274270  0.213186  0.084358   0.133562  0.039171  0.096987
# basement          0.182272  0.058447  0.102537   0.112671 -0.174413  0.044154
# hotwaterheating   0.091955 -0.026576  0.060704   0.075481  0.025946 -0.013049
# airconditioning   0.463935  0.288543  0.167839   0.195538  0.304648  0.108851
# parking           0.384147  0.384060  0.142377   0.188751  0.049203  0.202495
# ...

# %%
sns.heatmap(df.corr() ,annot=True)
plt.title('housing heatmap')
plt.show()

# %%
sns.boxplot(df['stories'])
plt.title('housing boxplot')
plt.figure(figsize=(100,40))
plt.show()

# %%
sns.distplot(df['parking'])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21304\523897210.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['parking'])

# %%
x1=[0.25,1.25,2.25,3.25]
x2=[0.5,1.5,2.5,3.5]
x3=[0.75,1.75,2.75,3.75]
x4=[1,2,3,4]

y1=df['parking']
y2=df['bedrooms']
y3=df['stories']
y4=df['airconditioning']

plt.bar(y1 , color='k' , label='parking' , width=0.4 , height=1)
plt.bar(y2, color='g' , label='bedrooms' , width=0.3,height=0.8)
plt.bar(y3, color='r' , label='stories' , width=0.2,height=0.5)
plt.bar(y4, color='m' , label='airconditioning' , width=0.5,height=0.2)

plt.title('bar graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.xticks(np.arange(1,6,step=1))
plt.xticks(np.arange(1,6,step=1))
plt.legend()
plt.show()
